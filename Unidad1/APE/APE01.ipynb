# %% [markdown]
# # APE01 - Variables Aleatorias y Distribuciones de Probabilidad
#
# Notebook base generado a partir de la guía.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ## Complete aquí las tareas de la guía.
# Este notebook sirve como plantilla editable.
